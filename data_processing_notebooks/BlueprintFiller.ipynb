# %%
import pandas as pd

# %%
# df = pd.read_csv('train_skip_no_refs_eng_blueprints_only_eng.csv', delimiter="\t")
df = pd.read_csv('train_only_eng_blueprints.csv', delimiter="\t")

# %%
def get_id(id):
  split_example_id = id.split('-')

  if len(split_example_id) == 3:
    return split_example_id[0] + split_example_id[2]
  elif len(split_example_id) == 4:
    return split_example_id[0] + split_example_id[1] + split_example_id[3]

def get_lang(id):
  split_example_id = id.split('-')

  if len(split_example_id) == 3:
    return split_example_id[1]
  elif len(split_example_id) == 4:
    return split_example_id[2]

# Extract language and id information from example_id
df['language'] = df['example_id'].apply(get_lang)
df['id'] = df['example_id'].apply(get_id)

# Identify English rows
english_rows = df[df['language'] == 'en']

# Create a dictionary mapping id to blueprint for English rows
blueprint_dict = dict(zip(english_rows['id'], english_rows['blueprint']))

# Update the blueprint column for other language rows
df['blueprint'] = df['id'].map(blueprint_dict)

# Drop the temporary columns 'language' and 'id'
df = df.drop(['language', 'id'], axis=1)

# Display the resulting DataFrame
print(df)
# Out:
#       example_id                                              title  \
# 0      AB20-ar-1  تمكين الشباب بين الشابات في الفئة العمرية من 1...
# 1      AB20-ar-2  العدد المثالي للأطفال وفقًا لمستوى التمكين - ن...
# 2      AB20-ar-3  العدد المثالي للأطفال وتمكين الشابات: تحليل مت...
# 3      AB20-ar-4  الاستخدام الحالي لوسائل منع الحمل والنية لاستخ...
# 4      AB20-en-1  Youth Empowerment among Young Women age 15-29 ...
# ...          ...                                                ...
# 4777  WP120-pt-2  Percentagem de mulheres que utilizavam diferen...
# 4778  WP120-sw-1  Kiwango cha kuenea kwa kingamimba kulingana na...
# 4779  WP120-sw-2  Asilimia ya wanawake waliotumia aina tofauti z...
# 4780  WP120-yo-1  Ìtànkálẹ̀ àwọn ohun èèlò ìfètòsọmọbi...
# 4781  WP120-yo-2  Ìdá nínú ìdá ọgọ́rùn àwọn obìnrin ló...
#
#                                         unit_of_measure            chart_type  \
# 0            النسبة المئوية موضحة في ثلاثة أجزاء مُجمعة  Horizontal Bar Chart
# 1     العدد بين الشابات في الفئة العمرية من 15 إلى 2...            Line Chart
# 2     معاملات تمكين الشابات للعدد المثالي للأطفال من...                 Other
# 3     النسبة المئوية بين الشابات في الفئة العمرية من...            Line Chart
# 4                         percentage in pooled terciles  Horizontal Bar Chart
# ...                                                 ...                   ...
# 4777                                            CPR (%)    Vertical Bar Chart
# 4778                                           Asilimia    Vertical Bar Chart
# 4779                                             CPR(%)    Vertical Bar Chart
# 4780         Òdiwọ̀n ìdá nínú ìdá ọgọ́ọ̀rún    Vertical Bar Chart
# 4781                  CPR (Ìdá nínú ìdá ọgọ́rùn)    Vertical Bar Chart
#
#       was_translated                                         table_data  \
# 0               True  [["", "\u0645\u0633\u062a\u0648\u0649 \u0639\u...
# 1               True  [["\u0645\u0633\u062a\u0648\u0649 \u0645\u0646...
# 2               True  [["", "\u0645\u0633\u062a\u0648\u0649 \u0645\u...
# 3               True  [["", "\u0627\u0644\u0646\u064a\u0629 \u0641\u...
# 4              False  [["", "High Empowerment", "Medium Empowerment"...
# ...              ...                                                ...
# 4777            True  [["M\u00e9todos injet\u00e1veis", 5.7], ["Pres...
# 4778            True  [["Njia yoyote", 0.256], ["Njia ya kisasa", 0....
# 4779            True  [["Sindano", 5.7], ["Kondomu ya mwanaume", 3.4...
# 4780            True  [["O\u0323\u0300na\u0300 a\u0300tis\u0323e e\u...
# 4781            True  [["A\u0300wo\u0323n to\u0301s\u0323e\u0301egu\...
#
#                                              table_text  \
# 0     ['تتمتع 13% من الشابات في مالي بأعلى مستويات ا...
# 1     ['في نيجيريا، ترغب الشابات ذوات المستوى المنخف...
# 2     ['تُظهر النماذج متعددة المتغيرات أنه في 5 بلدا...
# 3     ['في نيجيريا، تكون الشابات ذوات التمكين العالي...
# 4     ['Only 13% of young women in Mali are in the h...
# ...                                                 ...
# 4777  ['A Figura 4 descreve a combinação de métodos ...
# 4778  ['Kwa jumla, 26% ya wanawake walikuwa wanatumi...
# 4779  ['Kielelezo 4 kinaonyesha mseto wa njia za kis...
# 4780  ['Ní àpapọ̀, ìdá 26 nínú ìdá ọgọ́rùn ...
# 4781  ['Àwòrán 4 ṣàfihàn àlòpapọ̀ àwọn ohun ...
#
#                                        linearized_input  \
# 0     تمكين الشباب بين الشابات في الفئة العمرية من 1...
# 1     العدد المثالي للأطفال وفقًا لمستوى التمكين - ن...
# 2     العدد المثالي للأطفال وتمكين الشابات: تحليل مت...
# 3     الاستخدام الحالي لوسائل منع الحمل والنية لاستخ...
# 4     Youth Empowerment among Young Women age 15-29 ...
# ...                                                 ...
# 4777  Percentagem de mulheres que utilizavam diferen...
# 4778  Kiwango cha kuenea kwa kingamimba kulingana na...
# 4779  Asilimia ya wanawake waliotumia aina tofauti z...
# 4780  Ìtànkálẹ̀ àwọn ohun èèlò ìfètòsọmọbi...
# 4781  Ìdá nínú ìdá ọgọ́rùn àwọn obìnrin ló...
#
#                                                  target  \
# 0     تتمتع 13% من الشابات في مالي بأعلى مستويات الت...
# 1     في نيجيريا، ترغب الشابات ذوات المستوى المنخفض ...
# 2     تُظهر النماذج متعددة المتغيرات أنه في 5 بلدان،...
# 3     في نيجيريا، تكون الشابات ذوات التمكين العالي أ...
# 4     Only 13% of young women in Mali are in the hig...
# ...                                                 ...
# 4777  A Figura 4 descreve a combinação de métodos co...
# 4778  Kwa jumla, 26% ya wanawake walikuwa wanatumia ...
# 4779  Kielelezo 4 kinaonyesha mseto wa njia za kisas...
# 4780  Ní àpapọ̀, ìdá 26 nínú ìdá ọgọ́rùn à...
# 4781  Àwòrán 4 ṣàfihàn àlòpapọ̀ àwọn ohun è...
#
#                                               blueprint
# 0     ['13%. How much of young women in Mali are in ...
# 1     ['Average of 6.8 children. Would a Nigerian gi...
# 2     ['5. How many countries do Mutlivariable model...
# 3     ['high. In Nigeria, women with what type of em...
# 4     ['13%. How much of young women in Mali are in ...
# ...                                                 ...
# 4777  ['Figure 4. What figure depicts the method mix...
# 4778  ['26%. What percentage of women were using any...
# 4779  ['Figure 4. What figure depicts the method mix...
# 4780  ['26%. What percentage of women were using any...
# 4781  ['Figure 4. What figure depicts the method mix...
#
# [4782 rows x 10 columns]

# %%
df = df.dropna(subset=['blueprint'])

# %%
df[df['blueprint'].isna()]
# Out:
# Empty DataFrame
# Columns: [example_id, title, unit_of_measure, chart_type, was_translated, table_data, table_text, linearized_input, target, blueprint]
# Index: []

# %%
len(df)
# Out:
# 4778

# %%
# Write the updated DataFrame to a new CSV file
df.to_csv('train_eng_blueprints_all.csv', sep="\t", index=False)
